# %%
# Basic Import

import os
import pandas as pd
import numpy as np
import math
import datetime as dt

from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score, r2_score 
from sklearn.metrics import mean_poisson_deviance, mean_gamma_deviance, accuracy_score
from sklearn.preprocessing import MinMaxScaler


import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, Dropout, Dense, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2

from itertools import cycle
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

import seaborn as sns 
import matplotlib.pyplot as plt 

import warnings
warnings.filterwarnings('ignore')

# %%
## loading dataset
df = pd.read_csv('stock_data.csv')

# convert date field from string to Date format 
df['Date'] = pd.to_datetime(df.Date)
df.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close    Volume
# 0 2020-01-02  59.687500  59.977501  59.180000  59.977501  59.741245  23753600
# 1 2020-01-03  58.775002  59.457500  58.525002  59.017502  58.785023  20538400
# 2 2020-01-06  58.080002  59.317501  57.817501  59.264999  59.031548  26263600
# 3 2020-01-07  59.549999  60.442501  59.097500  59.982498  59.746220  31485600
# 4 2020-01-08  59.939999  60.509998  59.537498  60.095001  59.858280  27710800

# %%
# preparing data for training

df1 = df[['Date','Adj Close']]

# Renaming Adj Close
df1.rename(columns={'Adj Close': 'AdjClose'}, inplace=True)
print("Shape of close dataframe:", df1.shape)
# Out:
# Shape of close dataframe: (1092, 2)

# %%
# Consider only last 1 year data for prediction

df1 = df1[df1['Date'] > '2023-02-18']
close_stock = df1.copy()
print("Total data for prediction: ",df1.shape[0])
# Out:
# Total data for prediction:  303

# %%
# plotting adj close price for selected data

fig = px.line(df1, x=df1.Date, y=df1.AdjClose,labels={'Date':'Date','AdjClose':'Adj Close'})
fig.update_traces(marker_line_width=2, opacity=0.8)
fig.update_layout(title_text='Stock close price chart', plot_bgcolor='white', font_size=15, font_color='black')
fig.update_xaxes(showgrid=False)
fig.update_yaxes(showgrid=False)
fig.show()

# %%
# Scaling between 0-1

close_stock = df1.copy()
del df1['Date']
scaler=MinMaxScaler(feature_range=(0,1))
closedf=scaler.fit_transform(np.array(df1).reshape(-1,1))
print(closedf.shape)
# Out:
# (303, 1)

# %%
# train test split

training_size=int(len(closedf)*0.65)
test_size=len(closedf)-training_size
train_data,test_data=closedf[0:training_size,:],closedf[training_size:len(closedf),:1]
print("train_data: ", train_data.shape)
print("test_data: ", test_data.shape)
# Out:
# train_data:  (196, 1)
# test_data:  (107, 1)

# %%
# Create new dataset according to requirement of time-series prediction

# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %%
# reshape into X=t,t+1,t+2,t+3 and Y=t+4
time_step = 15
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

print("X_train: ", X_train.shape)
print("y_train: ", y_train.shape)
print("X_test: ", X_test.shape)
print("y_test", y_test.shape)
# Out:
# X_train:  (180, 15)
# y_train:  (180,)
# X_test:  (91, 15)
# y_test (91,)

# %%
# Model structure: LSTM+GRU

tf.keras.backend.clear_session()
model=Sequential()
model.add(LSTM(32,return_sequences=True,input_shape=(time_step,1)))
model.add(LSTM(32,return_sequences=True))
model.add(GRU(32,return_sequences=True))
model.add(GRU(32))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')
# Out:
# WARNING:tensorflow:From c:\Users\Personal\anaconda3\envs\stocks\lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 15, 32)         │         4,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 15, 32)         │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru (GRU)                       │ (None, 15, 32)         │         6,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 32)             │         6,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 25,377 (99.13 KB)
#  Trainable params: 25,377 (99.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=200,batch_size=5,verbose=1)
# Out:
# Epoch 1/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - loss: 0.0269 - val_loss: 0.0649
# Epoch 2/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0031 - val_loss: 0.0044
# Epoch 3/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0019 - val_loss: 0.0182
# Epoch 4/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0013 - val_loss: 0.0055
# Epoch 5/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0014 - val_loss: 0.0175
# Epoch 6/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0015 - val_loss: 0.0251
# Epoch 7/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0011 - val_loss: 0.0235
# Epoch 8/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0012 - val_loss: 0.0204
# Epoch 9/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 9.5394e-04 - val_loss: 0.0371
# Epoch 10/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0011 - val_loss: 0.0180
# Epoch 11/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0013 - val_loss: 0.0435
# Epoch 12/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0012 - val_loss: 0.0528
# Epoch 13/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0012 - val_loss: 0.0515
# Epoch 14/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0012 - val_loss: 0.0326
# Epoch 15/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.3569e-04 - val_loss: 0.0317
# Epoch 16/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.2707e-04 - val_loss: 0.0575
# Epoch 17/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0013 - val_loss: 0.0434
# Epoch 18/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 9.6731e-04 - val_loss: 0.0450
# Epoch 19/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 8.5420e-04 - val_loss: 0.0687
# Epoch 20/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 7.8895e-04 - val_loss: 0.0604
# Epoch 21/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.9686e-04 - val_loss: 0.0637
# Epoch 22/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.0191e-04 - val_loss: 0.0495
# Epoch 23/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 7.7466e-04 - val_loss: 0.0379
# Epoch 24/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.0915e-04 - val_loss: 0.0596
# Epoch 25/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.7993e-04 - val_loss: 0.0434
# Epoch 26/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.7355e-04 - val_loss: 0.0529
# Epoch 27/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.9001e-04 - val_loss: 0.0490
# Epoch 28/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.2565e-04 - val_loss: 0.0478
# Epoch 29/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.5643e-04 - val_loss: 0.0394
# Epoch 30/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.1915e-04 - val_loss: 0.0471
# Epoch 31/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.1022e-04 - val_loss: 0.0332
# Epoch 32/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.0373e-04 - val_loss: 0.0396
# Epoch 33/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.9949e-04 - val_loss: 0.0509
# Epoch 34/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.3829e-04 - val_loss: 0.0425
# Epoch 35/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.6748e-04 - val_loss: 0.0290
# Epoch 36/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.8318e-04 - val_loss: 0.0496
# Epoch 37/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.9640e-04 - val_loss: 0.0314
# Epoch 38/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.1899e-04 - val_loss: 0.0298
# Epoch 39/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.1304e-04 - val_loss: 0.0346
# Epoch 40/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 3.8507e-04 - val_loss: 0.0298
# Epoch 41/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.0057e-04 - val_loss: 0.0523
# Epoch 42/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.7538e-04 - val_loss: 0.0276
# Epoch 43/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.6432e-04 - val_loss: 0.0226
# Epoch 44/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.4755e-04 - val_loss: 0.0305
# Epoch 45/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.7878e-04 - val_loss: 0.0466
# Epoch 46/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.7540e-04 - val_loss: 0.0266
# Epoch 47/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.5027e-04 - val_loss: 0.0226
# Epoch 48/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.4325e-04 - val_loss: 0.0322
# Epoch 49/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.6713e-04 - val_loss: 0.0346
# Epoch 50/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.9793e-04 - val_loss: 0.0377
# Epoch 51/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.7374e-04 - val_loss: 0.0291
# Epoch 52/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.5128e-04 - val_loss: 0.0249
# Epoch 53/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.0477e-04 - val_loss: 0.0274
# Epoch 54/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.5483e-04 - val_loss: 0.0321
# Epoch 55/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.3143e-04 - val_loss: 0.0302
# Epoch 56/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.8185e-04 - val_loss: 0.0226
# Epoch 57/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.4036e-04 - val_loss: 0.0253
# Epoch 58/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.4500e-04 - val_loss: 0.0261
# Epoch 59/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.3066e-04 - val_loss: 0.0256
# Epoch 60/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.7767e-04 - val_loss: 0.0170
# Epoch 61/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.2042e-04 - val_loss: 0.0240
# Epoch 62/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.8460e-04 - val_loss: 0.0303
# Epoch 63/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.5571e-04 - val_loss: 0.0213
# Epoch 64/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.0357e-04 - val_loss: 0.0265
# Epoch 65/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.7420e-04 - val_loss: 0.0212
# Epoch 66/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.0864e-04 - val_loss: 0.0182
# Epoch 67/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.9464e-04 - val_loss: 0.0274
# Epoch 68/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.5001e-04 - val_loss: 0.0211
# Epoch 69/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.7284e-04 - val_loss: 0.0185
# Epoch 70/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.4310e-04 - val_loss: 0.0199
# Epoch 71/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.1106e-04 - val_loss: 0.0224
# Epoch 72/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.8321e-04 - val_loss: 0.0322
# Epoch 73/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.9142e-04 - val_loss: 0.0232
# Epoch 74/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.4198e-04 - val_loss: 0.0206
# Epoch 75/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.3446e-04 - val_loss: 0.0209
# Epoch 76/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.5040e-04 - val_loss: 0.0201
# Epoch 77/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.9717e-04 - val_loss: 0.0315
# Epoch 78/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.0408e-04 - val_loss: 0.0187
# Epoch 79/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.8832e-04 - val_loss: 0.0211
# Epoch 80/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.3345e-04 - val_loss: 0.0181
# Epoch 81/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.5696e-04 - val_loss: 0.0206
# Epoch 82/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.7558e-04 - val_loss: 0.0240
# Epoch 83/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.2150e-04 - val_loss: 0.0179
# Epoch 84/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.8757e-04 - val_loss: 0.0265
# Epoch 85/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.0208e-04 - val_loss: 0.0286
# Epoch 86/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.0351e-04 - val_loss: 0.0223
# Epoch 87/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.1187e-04 - val_loss: 0.0218
# Epoch 88/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.1511e-04 - val_loss: 0.0189
# Epoch 89/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.9902e-04 - val_loss: 0.0308
# Epoch 90/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.0565e-04 - val_loss: 0.0229
# Epoch 91/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.7052e-04 - val_loss: 0.0174
# Epoch 92/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.3388e-04 - val_loss: 0.0347
# Epoch 93/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.5129e-04 - val_loss: 0.0194
# Epoch 94/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.8702e-04 - val_loss: 0.0187
# Epoch 95/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.3520e-04 - val_loss: 0.0224
# Epoch 96/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.6770e-04 - val_loss: 0.0158
# Epoch 97/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.5315e-04 - val_loss: 0.0223
# Epoch 98/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 2.1455e-04 - val_loss: 0.0284
# Epoch 99/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.9680e-04 - val_loss: 0.0158
# Epoch 100/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 2.1283e-04 - val_loss: 0.0175
# Epoch 101/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 2.9919e-04 - val_loss: 0.0241
# Epoch 102/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 2.7591e-04 - val_loss: 0.0258
# Epoch 103/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 2.5844e-04 - val_loss: 0.0195
# Epoch 104/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 2.4230e-04 - val_loss: 0.0220
# Epoch 105/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 2.5954e-04 - val_loss: 0.0310
# Epoch 106/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.0183e-04 - val_loss: 0.0163
# Epoch 107/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.4270e-04 - val_loss: 0.0230
# Epoch 108/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.8948e-04 - val_loss: 0.0242
# Epoch 109/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.8956e-04 - val_loss: 0.0259
# Epoch 110/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.9103e-04 - val_loss: 0.0196
# Epoch 111/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.2005e-04 - val_loss: 0.0252
# Epoch 112/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.2236e-04 - val_loss: 0.0242
# Epoch 113/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.6843e-04 - val_loss: 0.0198
# Epoch 114/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.6314e-04 - val_loss: 0.0169
# Epoch 115/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.2785e-04 - val_loss: 0.0230
# Epoch 116/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.8762e-04 - val_loss: 0.0185
# Epoch 117/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.3977e-04 - val_loss: 0.0218
# Epoch 118/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.9158e-04 - val_loss: 0.0203
# Epoch 119/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.7402e-04 - val_loss: 0.0216
# Epoch 120/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.0314e-04 - val_loss: 0.0195
# Epoch 121/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.5440e-04 - val_loss: 0.0211
# Epoch 122/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.9469e-04 - val_loss: 0.0222
# Epoch 123/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.9543e-04 - val_loss: 0.0283
# Epoch 124/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.4256e-04 - val_loss: 0.0262
# Epoch 125/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.8551e-04 - val_loss: 0.0181
# Epoch 126/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.2943e-04 - val_loss: 0.0293
# Epoch 127/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.0428e-04 - val_loss: 0.0303
# Epoch 128/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.1923e-04 - val_loss: 0.0184
# Epoch 129/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.2171e-04 - val_loss: 0.0250
# Epoch 130/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.4494e-04 - val_loss: 0.0238
# Epoch 131/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.1392e-04 - val_loss: 0.0270
# Epoch 132/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.6488e-04 - val_loss: 0.0248
# Epoch 133/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.0650e-04 - val_loss: 0.0293
# Epoch 134/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.4746e-04 - val_loss: 0.0238
# Epoch 135/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.3585e-04 - val_loss: 0.0250
# Epoch 136/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.1355e-04 - val_loss: 0.0275
# Epoch 137/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.8506e-04 - val_loss: 0.0218
# Epoch 138/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.6634e-04 - val_loss: 0.0220
# Epoch 139/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.9574e-04 - val_loss: 0.0154
# Epoch 140/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.6769e-04 - val_loss: 0.0245
# Epoch 141/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.7267e-04 - val_loss: 0.0267
# Epoch 142/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.0576e-04 - val_loss: 0.0346
# Epoch 143/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.1378e-04 - val_loss: 0.0272
# Epoch 144/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.3541e-04 - val_loss: 0.0432
# Epoch 145/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.1637e-04 - val_loss: 0.0310
# Epoch 146/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.8887e-04 - val_loss: 0.0391
# Epoch 147/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.7999e-04 - val_loss: 0.0346
# Epoch 148/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.2545e-04 - val_loss: 0.0310
# Epoch 149/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.1434e-04 - val_loss: 0.0187
# Epoch 150/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.3856e-04 - val_loss: 0.0309
# Epoch 151/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.2389e-04 - val_loss: 0.0397
# Epoch 152/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.8822e-04 - val_loss: 0.0398
# Epoch 153/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.0679e-04 - val_loss: 0.0283
# Epoch 154/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.3186e-04 - val_loss: 0.0350
# Epoch 155/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.4426e-04 - val_loss: 0.0286
# Epoch 156/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.1058e-04 - val_loss: 0.0329
# Epoch 157/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.6377e-04 - val_loss: 0.0301
# Epoch 158/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.3895e-04 - val_loss: 0.0291
# Epoch 159/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.0289e-04 - val_loss: 0.0336
# Epoch 160/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.3213e-04 - val_loss: 0.0309
# Epoch 161/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.9727e-04 - val_loss: 0.0283
# Epoch 162/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.6441e-04 - val_loss: 0.0343
# Epoch 163/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 2.2165e-04 - val_loss: 0.0373
# Epoch 164/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.0131e-04 - val_loss: 0.0330
# Epoch 165/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.7218e-04 - val_loss: 0.0383
# Epoch 166/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.0950e-04 - val_loss: 0.0306
# Epoch 167/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.3749e-04 - val_loss: 0.0452
# Epoch 168/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.8961e-04 - val_loss: 0.0370
# Epoch 169/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.1223e-04 - val_loss: 0.0348
# Epoch 170/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.3308e-04 - val_loss: 0.0361
# Epoch 171/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.0798e-04 - val_loss: 0.0381
# Epoch 172/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.7228e-04 - val_loss: 0.0284
# Epoch 173/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.6127e-04 - val_loss: 0.0373
# Epoch 174/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.5118e-04 - val_loss: 0.0276
# Epoch 175/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.1491e-04 - val_loss: 0.0363
# Epoch 176/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.0349e-04 - val_loss: 0.0255
# Epoch 177/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.2894e-04 - val_loss: 0.0403
# Epoch 178/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.6410e-04 - val_loss: 0.0396
# Epoch 179/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.8289e-04 - val_loss: 0.0321
# Epoch 180/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.1759e-04 - val_loss: 0.0320
# Epoch 181/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.6061e-04 - val_loss: 0.0482
# Epoch 182/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.5928e-04 - val_loss: 0.0294
# Epoch 183/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.0717e-04 - val_loss: 0.0326
# Epoch 184/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.3991e-04 - val_loss: 0.0312
# Epoch 185/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2.7613e-04 - val_loss: 0.0424
# Epoch 186/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.4587e-04 - val_loss: 0.0370
# Epoch 187/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.2784e-04 - val_loss: 0.0445
# Epoch 188/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.1285e-04 - val_loss: 0.0338
# Epoch 189/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.0153e-04 - val_loss: 0.0318
# Epoch 190/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.7417e-04 - val_loss: 0.0366
# Epoch 191/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.0281e-04 - val_loss: 0.0351
# Epoch 192/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.5305e-04 - val_loss: 0.0422
# Epoch 193/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.3360e-04 - val_loss: 0.0447
# Epoch 194/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.9882e-04 - val_loss: 0.0255
# Epoch 195/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.5535e-04 - val_loss: 0.0412
# Epoch 196/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.1289e-04 - val_loss: 0.0294
# Epoch 197/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.0359e-04 - val_loss: 0.0367
# Epoch 198/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.2134e-04 - val_loss: 0.0381
# Epoch 199/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.6820e-04 - val_loss: 0.0399
# Epoch 200/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.4933e-04 - val_loss: 0.0308

# %%
### Lets Do the prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
train_predict.shape, test_predict.shape
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# ((180, 1), (91, 1))

# %%
# Transform back to original form

train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)
original_ytrain = scaler.inverse_transform(y_train.reshape(-1,1)) 
original_ytest = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
# shift train predictions for plotting

look_back=time_step
trainPredictPlot = np.empty_like(closedf)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
print("Train predicted data: ", trainPredictPlot.shape)

# shift test predictions for plotting
testPredictPlot = np.empty_like(closedf)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(closedf)-1, :] = test_predict
print("Test predicted data: ", testPredictPlot.shape)

names = cycle(['Original close price','Train predicted close price','Test predicted close price'])

plotdf = pd.DataFrame({'date': close_stock['Date'],
                       'original_close': close_stock['AdjClose'],
                      'train_predicted_close': trainPredictPlot.reshape(1,-1)[0].tolist(),
                      'test_predicted_close': testPredictPlot.reshape(1,-1)[0].tolist()})

fig = px.line(plotdf,x=plotdf['date'], y=[plotdf['original_close'],plotdf['train_predicted_close'],
                                          plotdf['test_predicted_close']],
              labels={'value':'Stock price','date': 'Date'})
fig.update_layout(title_text='Comparision between original close price vs predicted close price',
                  plot_bgcolor='white', font_size=15, font_color='black', legend_title_text='Close Price')
fig.for_each_trace(lambda t:  t.update(name = next(names)))

fig.update_xaxes(showgrid=False)
fig.update_yaxes(showgrid=False)
fig.show()
# Out:
# Train predicted data:  (303, 1)
# Test predicted data:  (303, 1)
